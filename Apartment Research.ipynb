# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера</b>
#
# Привет! Прошу прощения за задержку ревью 🙏 Понимаю, что это принесло много неудобств, но скоро все будет в норме.
#
#
#
# Меня зовут Светлана Носова, я буду проверять твой проект. Если не против, давай общаться на «ты». Если тебе такой стиль общения не нравится, напиши об этом, будем на «вы».
#
# Сразу хочу обратить внимание на цветовую разметку:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Зеленым с пометкой ✔️ отмечены отличные решения и идеи, которые можно и нужно использовать в будущем.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Желтым с пометкой ⚠️ отмечено то, что можно или нужно оптимизировать, в зависимости от контекста.</div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Красным с пометкой ❌ обозначены пропущенные пункты задания и ошибки, которые обязательно надо будет исправить, чтобы результаты были верные.</div>
#
# **Ответы на мои комментарии или доработки по моим рекомендациям попрошу выделить каким-нибудь цветом, кроме перечисленных.**
# Также я попрошу тебя **не менять, не передвигать и не удалять мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# Кроме того, комментарии у меня обозначены как заголовки. Это сбивает содержание, но при последующей проверке я могу снять с них заголовок, если тебе так будет удобнее. При этом они удобны, поскольку ты сразу можешь перейти к ним.
#
# <hr>
#
# <font color= 'dodgerblue'>**По проекту:**</font> работа очень объемная и непростая, ты молодец. Структура отличная, много анализа, графиков и выводов. Здорово проработаны пропущенные значения и выбросы. В работе есть одна опечатка, также я предлагаю сократить радиус центра. Все написала в комментариях. Там же я оставила рекомендации по улучшению проекта. Буду ждать работу на повторное ревью.
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 2</b>
#
# Спасибо за корректировки. Я оставила новые комментарии с цифрой 2, а со старых сняла заголовки, чтобы  не мешали. Проект я могу принять, поскольку вопросов больше нет. Желаю успехов в дальнейшем обучении :)
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-столбцов,-относящихся-к-непосредственным-характеристикам-квартиры" data-toc-modified-id="Обработка-столбцов,-относящихся-к-непосредственным-характеристикам-квартиры-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка столбцов, относящихся к непосредственным характеристикам квартиры</a></span><ul class="toc-item"><li><span><a href="#''total_images'" data-toc-modified-id="''total_images'-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>''total_images'</a></span></li><li><span><a href="#'last_price'" data-toc-modified-id="'last_price'-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>'last_price'</a></span></li><li><span><a href="#'total_area'" data-toc-modified-id="'total_area'-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>'total_area'</a></span></li><li><span><a href="#'first_day_exposition'" data-toc-modified-id="'first_day_exposition'-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>'first_day_exposition'</a></span></li><li><span><a href="#'rooms'" data-toc-modified-id="'rooms'-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>'rooms'</a></span></li><li><span><a href="#'ceiling_height'" data-toc-modified-id="'ceiling_height'-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>'ceiling_height'</a></span></li><li><span><a href="#'floors_total'" data-toc-modified-id="'floors_total'-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>'floors_total'</a></span></li></ul></li></ul></li><li><span><a href="#-Комментарий-ревьюера-2-✔️" data-toc-modified-id="-Комментарий-ревьюера-2-✔️-3"><span class="toc-item-num">3&nbsp;&nbsp;</span> Комментарий ревьюера 2 ✔️</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#'balcony'" data-toc-modified-id="'balcony'-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>'balcony'</a></span></li><li><span><a href="#'kitchen_area'" data-toc-modified-id="'kitchen_area'-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>'kitchen_area'</a></span></li><li><span><a href="#'living_area'" data-toc-modified-id="'living_area'-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>'living_area'</a></span></li><li><span><a href="#'floor'" data-toc-modified-id="'floor'-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>'floor'</a></span></li><li><span><a href="#'is_apartment'" data-toc-modified-id="'is_apartment'-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>'is_apartment'</a></span></li><li><span><a href="#'studio'" data-toc-modified-id="'studio'-3.0.6"><span class="toc-item-num">3.0.6&nbsp;&nbsp;</span>'studio'</a></span></li><li><span><a href="#'open_plan'" data-toc-modified-id="'open_plan'-3.0.7"><span class="toc-item-num">3.0.7&nbsp;&nbsp;</span>'open_plan'</a></span></li><li><span><a href="#'locality_name'" data-toc-modified-id="'locality_name'-3.0.8"><span class="toc-item-num">3.0.8&nbsp;&nbsp;</span>'locality_name'</a></span></li><li><span><a href="#'city_centers_nearest'" data-toc-modified-id="'city_centers_nearest'-3.0.9"><span class="toc-item-num">3.0.9&nbsp;&nbsp;</span>'city_centers_nearest'</a></span></li><li><span><a href="#'days_exposition'" data-toc-modified-id="'days_exposition'-3.0.10"><span class="toc-item-num">3.0.10&nbsp;&nbsp;</span>'days_exposition'</a></span></li></ul></li><li><span><a href="#Столбцы-с-географическими-особенностями" data-toc-modified-id="Столбцы-с-географическими-особенностями-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Столбцы с географическими особенностями</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-за-кв.м.-от-дня-недели" data-toc-modified-id="Зависимость-цены-за-кв.м.-от-дня-недели-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Зависимость цены за кв.м. от дня недели</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-цены-за-кв.м.-от-месяца" data-toc-modified-id="Зависимость-цены-за-кв.м.-от-месяца-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Зависимость цены за кв.м. от месяца</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-цены-за-кв.м.--от-года" data-toc-modified-id="Зависимость-цены-за-кв.м.--от-года-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Зависимость цены за кв.м.  от года</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-цены-за-кв.м-от-этажа-квартиры" data-toc-modified-id="Зависимость-цены-за-кв.м-от-этажа-квартиры-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Зависимость цены за кв.м от этажа квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-цены-за-кв.м.-от-площади-квартиры" data-toc-modified-id="Зависимость-цены-за-кв.м.-от-площади-квартиры-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Зависимость цены за кв.м. от площади квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-цены-за-кв.м.-от-числа-комнат" data-toc-modified-id="Зависимость-цены-за-кв.м.-от-числа-комнат-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Зависимость цены за кв.м. от числа комнат</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-цены-за-кв.м.-от-удаленности-от-центра" data-toc-modified-id="Зависимость-цены-за-кв.м.-от-удаленности-от-центра-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Зависимость цены за кв.м. от удаленности от центра</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.7.1"><span class="toc-item-num">5.7.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Большая-десятка" data-toc-modified-id="Большая-десятка-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Большая десятка</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.8.1"><span class="toc-item-num">5.8.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Санкт---Петербург" data-toc-modified-id="Санкт---Петербург-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Санкт - Петербург</a></span><ul class="toc-item"><li><span><a href="#Цены/удаленности-от-центра,-поиск-центра-города" data-toc-modified-id="Цены/удаленности-от-центра,-поиск-центра-города-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Цены/удаленности от центра, поиск центра города</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-квартир-в-центре" data-toc-modified-id="Анализ-квартир-в-центре-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Анализ квартир в центре</a></span><ul class="toc-item"><li><span><a href="#Анализ-площади-квартир-в-центре" data-toc-modified-id="Анализ-площади-квартир-в-центре-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Анализ площади квартир в центре</a></span></li><li><span><a href="#Анализ-высоты-потолков-в-центре" data-toc-modified-id="Анализ-высоты-потолков-в-центре-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Анализ высоты потолков в центре</a></span></li><li><span><a href="#Анализ-числа-комнат-в-квартирах-центра" data-toc-modified-id="Анализ-числа-комнат-в-квартирах-центра-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Анализ числа комнат в квартирах центра</a></span></li></ul></li></ul></li><li><span><a href="#-Комментарий-ревьюера-2-✔️" data-toc-modified-id="-Комментарий-ревьюера-2-✔️-7"><span class="toc-item-num">7&nbsp;&nbsp;</span> Комментарий ревьюера 2 ✔️</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Зависимость-цены-за-кв.м-от-этажа-квартиры" data-toc-modified-id="Зависимость-цены-за-кв.м-от-этажа-квартиры-7.0.1"><span class="toc-item-num">7.0.1&nbsp;&nbsp;</span>Зависимость цены за кв.м от этажа квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.0.1.1"><span class="toc-item-num">7.0.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-цены-за-кв.м-от-площади-квартиры" data-toc-modified-id="Зависимость-цены-за-кв.м-от-площади-квартиры-7.0.2"><span class="toc-item-num">7.0.2&nbsp;&nbsp;</span>Зависимость цены за кв.м от площади квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.0.2.1"><span class="toc-item-num">7.0.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-цены-за-кв.м-от-числа-комнат" data-toc-modified-id="Зависимость-цены-за-кв.м-от-числа-комнат-7.0.3"><span class="toc-item-num">7.0.3&nbsp;&nbsp;</span>Зависимость цены за кв.м от числа комнат</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.0.3.1"><span class="toc-item-num">7.0.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зависимость-стоимости-от-даты-размещения" data-toc-modified-id="Зависимость-стоимости-от-даты-размещения-7.0.4"><span class="toc-item-num">7.0.4&nbsp;&nbsp;</span>Зависимость стоимости от даты размещения</a></span><ul class="toc-item"><li><span><a href="#От-года-размещения" data-toc-modified-id="От-года-размещения-7.0.4.1"><span class="toc-item-num">7.0.4.1&nbsp;&nbsp;</span>От года размещения</a></span></li><li><span><a href="#От-месяца-размещения" data-toc-modified-id="От-месяца-размещения-7.0.4.2"><span class="toc-item-num">7.0.4.2&nbsp;&nbsp;</span>От месяца размещения</a></span></li><li><span><a href="#От-дня-размещения" data-toc-modified-id="От-дня-размещения-7.0.4.3"><span class="toc-item-num">7.0.4.3&nbsp;&nbsp;</span>От дня размещения</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Сводная-таблица-по-характеристикам" data-toc-modified-id="Сводная-таблица-по-характеристикам-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Сводная таблица по характеристикам</a></span><ul class="toc-item"><li><span><a href="#Вся-выборка" data-toc-modified-id="Вся-выборка-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Вся выборка</a></span></li><li><span><a href="#Выборка-по--Санкт-Петербургу" data-toc-modified-id="Выборка-по--Санкт-Петербургу-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Выборка по  Санкт-Петербургу</a></span></li><li><span><a href="#Выборка-по-центру-Санкт---Петербурга" data-toc-modified-id="Выборка-по-центру-Санкт---Петербурга-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Выборка по центру Санкт - Петербурга</a></span></li></ul></li><li><span><a href="#-Комментарий-ревьюера-2-✔️" data-toc-modified-id="-Комментарий-ревьюера-2-✔️-10"><span class="toc-item-num">10&nbsp;&nbsp;</span> Комментарий ревьюера 2 ✔️</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
from datetime import datetime, date, time
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\\t',engine='python')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# Данные "склеились", применим функции для разделения значений по столбцам *sep*

# %% [markdown]
# ### Вывод

# %% [markdown]
# Выведем первые 10 значений для общего понимания данных и наличие пустых значений,ошибок,неправильного формата дат и других возможных проблем.

# %%
display(df.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# **Проблемы**:
# - Цену в колонке *'last price'* лучше будет для удобства привести в целочисленный формат из вещественного;
# - Изменить формат даты в колонке *'first_day_exposition'*;
# - Разобраться с пропусками  колонке *'ceiling_height'*;
# - Колонку *'floors_total'* привести к целочисленному виду;
# - Рассмотреть пропуски в данных в колонке *'living_area'*. На эту колонку обратить особое внимание, т.к. жилая площадь является критически важным параметром;
# - Отработать пропущенные значения в колонке *'is_apartment'*,булев тип данных,привести к целочисленному по типу 0 - нет, 1 - да;
# - В колонке *'kitchen_area'* по возможности заполнить пропуски;
# - Разобраться в колонке *'balcony'*, что делать с пропусками;
# - Привести *'locality_name'*  по возможности к более читаемомму формату;
# - Для колонки *'airports_nearest'* заполнить пропуски;
# - Заполнить пропуски и переименовать колонку *'cityCenters_nearest'* по правилам хорошего наименования;
# - То же самое с колонкой *'parks_around3000'*, плюс привести к целочисленному виду;
# - В остальных колонках наблюдаются те же проблемы.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Отличная вводная часть: и содержание, и описание задачи и краткий вывод.
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка столбцов, относящихся к непосредственным характеристикам квартиры

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Если вывести в процентах, то станет понятнее, насколько много пропусков у нас. Кстати, можно добавить краски:</div>

# %%
# КОД РЕВЬЮЕРА

pd.DataFrame(df.isna().mean().round(4)*100).sort_values(by=0)[::-1].style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
#     #T_67e4c818_8271_11ec_8f30_02420a3944barow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_67e4c818_8271_11ec_8f30_02420a3944barow1_col0 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_67e4c818_8271_11ec_8f30_02420a3944barow2_col0 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_67e4c818_8271_11ec_8f30_02420a3944barow3_col0 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_67e4c818_8271_11ec_8f30_02420a3944barow4_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_67e4c818_8271_11ec_8f30_02420a3944barow5_col0 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_67e4c818_8271_11ec_8f30_02420a3944barow6_col0 {
#             background-color:  #92b4fe;
#             color:  #000000;
# ...

# %% [markdown]
# Почти во всех колонках встречается много пропущенных значений, которые мы в дальнейшем будет либо отрабатывать и заполнять, либо отбрасывать. Так же датафрейм отображается не полностью,хорошей идеей будет разделить его на конструктивные блоки по принципу особенности помещения\особенности расположения.

# %% [markdown]
# Так же поменяем название колонки:

# %%
df.rename(columns={'cityCenters_nearest': 'city_centers_nearest'},inplace=True)

# %%
df.drop_duplicates()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
df_flat_prop = df[['total_images',
                             'last_price',
                             'total_area',
                             'first_day_exposition',
                             'rooms',
                             'ceiling_height',
                             'floors_total',
                             'living_area',
                             'floor',
                             'is_apartment',
                             'studio',
                             'open_plan',
                             'kitchen_area',
                             'balcony',
                             'locality_name',
                             'city_centers_nearest',
                             'days_exposition']]
df_place_prop = df[['last_price',
                              'floors_total',
                              'locality_name',
                              'airports_nearest',
                              'city_centers_nearest',
                              'parks_around3000',
                              'parks_nearest',
                              'ponds_around3000',
                              'ponds_nearest']]
df_flat_prop.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0        51.00      8          NaN   False
# ...

# %% [markdown]
# #### ''total_images'

# %% [markdown]
# Итак, рассмотрим первую колонку, 'total_images'.

# %%
df_flat_prop['total_images'].unique()
# Out:
# array([20,  7, 10,  0,  2,  6,  5, 18,  9,  1, 16, 11,  8, 12, 13,  3, 15,
#        17, 14, 19, 32,  4, 35, 39, 23, 21, 27, 30, 24, 25, 28, 31, 22, 29,
#        26, 50, 42, 37])

# %% [markdown]
# Все числа в целом нормальные. Единственное, что беспокоит - 0 картинок. Явно не увеличивает вероятность продажи. Надо посмотреть.сколько таких значений. И в целом взглянуть на распределение значений.

# %%
df_flat_prop['total_images'].value_counts(ascending = False)
# Out:
# 10    1798
# 9     1725
# 20    1694
# 8     1585
# 7     1521
# 6     1482
# 11    1362
# 5     1301
# 12    1225
# 0     1059
# 13    1015
# 14     986
# 4      986
# 15     948
# 1      872
# 3      769
# 16     761
# 17     650
# 18     642
# 2      640
# 19     603
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 28       4
# 32       4
# 50       3
# 29       3
# 31       2
# 35       2
# 30       2
# 27       2
# 37       1
# 39       1
# 25       1
# 42       1
# Name: total_images, dtype: int64

# %% [markdown]
# Чаще всего публикуют от 5 до 20 картинок в объявлении, похоже на правду. Однако 1059 значений это много. Почти пять процентов данных, просто не откинешь. Стоит взглянуть на остальные столбцы этих предложений.

# %%
df_flat_prop[df_flat_prop['total_images'] == 0].head(10)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 3               0  64900000.0       159.0  2015-07-24T00:00:00      3
# 62              0   4800000.0        78.6  2017-09-17T00:00:00      3
# 88              0   1700000.0        33.1  2019-04-09T00:00:00      1
# 129             0   3200000.0        32.0  2018-02-01T00:00:00      1
# 166             0   2300000.0        60.0  2017-12-02T00:00:00      2
# 169             0   6180000.0        85.0  2017-06-02T00:00:00      3
# 189             0   6150000.0        62.0  2017-10-13T00:00:00      3
# 212             0  10018000.0        82.0  2015-01-29T00:00:00      3
# 235             0   4000000.0        60.0  2019-03-12T00:00:00      2
# 256             0   5350000.0        65.6  2018-02-01T00:00:00      3
#
#      ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 3               NaN          14.0          NaN      9          NaN   False
# ...

# %% [markdown]
# В целом с первого взгляда большая часть колонок не вызывают подозрений, разве что объявления с индексами 88 и 166 имеют крайне мало данных. Возможно, объявление размещал пожилой человек и объявление - это собственность по типу загородного дома в поселке. К этим данным вернемся чуть позже.

# %% [markdown]
# Пока рассмотрим колонку *'last_price'*.

# %% [markdown]
# #### 'last_price'

# %%
# Посмотрим на цифры в целом
df_flat_prop['last_price'].value_counts(ascending = False)
#Цифры на вид адекватные, проверим есть ли нулевые значения и пропуски
print(df_flat_prop[df_flat_prop['last_price']==0].head())
df_flat_prop[df_flat_prop['last_price'].isna()==True].count()
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, city_centers_nearest, days_exposition]
# Index: []
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# city_centers_nearest    0
# days_exposition         0
# dtype: int64

# %% [markdown]
# Тут с данными всё в порядке, тогда просто пересчитаем на миллионы для лучшего отображения.

# %%
df_flat_prop['last_price'] = df_flat_prop['last_price']/1000000
df_flat_prop.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000       108.0  2019-03-07T00:00:00      3
# 1             7       3.350        40.4  2018-12-04T00:00:00      1
# 2            10       5.196        56.0  2015-08-20T00:00:00      2
# 3             0      64.900       159.0  2015-07-24T00:00:00      3
# 4             2      10.000       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  city_centers_nearest  \
# ...

# %% [markdown]
# Так же рассмаотрим колонку *'total_area'*

# %% [markdown]
# #### 'total_area'

# %%
print(df_flat_prop['total_area'].value_counts(ascending = True))
#Меняя значение 'ascending' ниже можно оценить,есть ли какие-то слишком низкие или слишком высокие значения.
#print(df_flat_prop.sort_values('total_area',ascending = False))
df_flat_prop['total_area'].isna().sum()
# Out:
# 23.55       1
# 127.20      1
# 59.83       1
# 44.18       1
# 45.85       1
#          ...
# 44.00     345
# 31.00     346
# 60.00     347
# 42.00     383
# 45.00     419
# Name: total_area, Length: 2182, dtype: int64
# 0

# %% [markdown]
# Пропущенных значений нет,распределение нормальное, встречаются совсем небольшой метраж, 4 м, а так же довольно большой - 900. Далее разберем эти данные на основе диаграмм и посмотрим, не является ли  это выбросами.

# %%
df_flat_prop['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
df_flat_prop.plot(x = 'last_price',
                  y = 'total_area',
                  kind = 'box', 
                  ylim = (0, 1000), 
                  figsize = (5,10));

# %% [markdown]
# Так и есть,есть четыре значения столбца, которые выбиваются из среднестатистических данных,похоже на выброс. Попробуем посмотреть не диаграмму размаха, а распределение.

# %%
ax = df_flat_prop.sort_values('total_area').plot(x = 'last_price',
                                            y = 'total_area',
                                            title = 'График распределения по размеру жилой площади',
                                            kind = 'scatter', 
                                            ylim = (0, 900),
                                            xlim = (0,1000),
                                            figsize = (10,5))
ax.set_xlabel('Последняя цена, млн')
ax.set_ylabel('Общая площдь,кв.м.');

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Здорово, что подписываешь графики.
# </div>

# %% [markdown]
# Для улучшения входных данных, придётся убрать записи площади которые превышают 200 кв.м и ценой выше 100 миллионов. Их крайне мало, не скажется на качестве данных.

# %%
df_flat_propf = df_flat_prop.query('total_area <200')
df_flat_propf = df_flat_propf.query('last_price <100')
df_flat_propf.tail()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9       9.700      133.81  2017-03-21T00:00:00      3
# 23695            14       3.100       59.00  2018-01-15T00:00:00      3
# 23696            18       2.500       56.70  2018-02-11T00:00:00      2
# 23697            13      11.475       76.75  2017-03-28T00:00:00      2
# 23698             4       1.350       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23694             3.7           5.0         73.3      3          NaN   False
# 23695             NaN           5.0         38.0      4          NaN   False
# 23696             NaN           3.0         29.7      1          NaN   False
# 23697             3.0          17.0          NaN     12          NaN   False
# 23698             2.5           5.0         12.3      1          NaN   False
#
#        open_plan  kitchen_area  balcony        locality_name  \
# ...

# %%
ax = df_flat_prop.sort_values('total_area').plot(x = 'last_price',
                                            y = 'total_area',
                                            title = 'График распределения по размеру жилой площади',
                                            kind = 'scatter', 
                                            ylim = (0, 400),
                                            xlim = (0,100),
                                            figsize = (10,5))
ax.set_xlabel('Последняя цена, млн')
ax.set_ylabel('Общая площдь,кв.м.');

# %% [markdown]
# #### 'first_day_exposition'

# %% [markdown]
# Теперь изменим столбец с датой, приведя его к нормальному формату,используя метод *to_datetime()*.

# %%
df_flat_propf['first_day_exposition'] = pd.to_datetime(df_flat_propf['first_day_exposition'],format = '%Y-%m-%dT');
df_flat_propf.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000       108.0           2019-03-07      3
# 1             7       3.350        40.4           2018-12-04      1
# 2            10       5.196        56.0           2015-08-20      2
# 3             0      64.900       159.0           2015-07-24      3
# 4             2      10.000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  city_centers_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# При чтении файла можно указать параметр **parse_dates**: `parse_dates=['first_day_exposition']`. Тогда пандас автоматически переведет список столбцов в даты.
#
# </div>

# %% [markdown]
# #### 'rooms'

# %%
#Посмотрим в целом на значения
print(df_flat_propf['rooms'].value_counts(ascending = False))
# А так же проверим есть ли нулевые значения в данной колонке
df_flat_propf['rooms'].isna().sum()
# Out:
# 1     8046
# 2     7939
# 3     5796
# 4     1135
# 5      264
# 0      196
# 6       62
# 7       20
# 11       2
# 8        2
# Name: rooms, dtype: int64
# 0

# %% [markdown]
# Уберем значения больше 7 комнат, так как они являются единичными и будут сильно смещать статистические данные,увеличивая погрешность и уменьшая точность анализа. Так же посмотрим квартиры с 0 комнат.

# %%
df_flat_propf = df_flat_propf.query('rooms <= 7')
df_flat_propf[df_flat_propf['rooms'] == 0].head()
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 144             1       2.450       27.00           2017-03-30      0
# 349             4       2.320       25.00           2017-09-27      0
# 440             8       2.480       27.11           2018-03-12      0
# 508             0       3.375       34.40           2017-03-28      0
# 608             2       1.850       25.00           2019-02-20      0
#
#      ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 144             NaN          24.0        15.50      2          NaN    True
# 349             NaN          14.0        17.00      1          NaN   False
# 440             NaN          17.0        24.75      4          NaN    True
# 508             NaN          26.0        24.30     19          NaN   False
# 608             NaN          10.0          NaN      7          NaN    True
#
#      open_plan  kitchen_area  balcony      locality_name  \
# ...

# %% [markdown]
# Судя по малому метражу и  параметрам 'open plan' == True либо 'studio' == True , это квартиры-студии,в которых в принципе нет деления на комнаты и квартиры со свободной планировкой, где нет разделения на них. Таким образом, эти строки мы оставляем.

# %% [markdown]
# #### 'ceiling_height'

# %% [markdown]
# В столбце с высотой потолков часто встречаются пропущенные значения, оценим их количество.

# %%
df_flat_propf['ceiling_height'].isna().sum()
# Out:
# 9112

# %% [markdown]
# **9179** значения - пропущено приблизительно в  38% объявлений. Слишком большой процент,чтобы не заменить их на характерное. Можно попробовать заменить на медианное для группы.

# %%
# Можно попробовать сделать сводную таблицу
df_flat_propf.pivot_table(index = 'locality_name',
                          values = 'ceiling_height',
                          aggfunc = ['mean','median'])
#Получилось интересно,но во многих значениях для каждого из городов стоят нулевые значения, 
#посмотрим описание значений в целом по столбцу.
df_flat_propf['ceiling_height'].describe()
# Out:
# count    14346.000000
# mean         2.764246
# std          1.264707
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Сегодня минимальной нормой в России считается высота потолка 2,4 метра. В новостройках обычно это значение находится в пределах [2,5-2,7](https://stone-floor.ru/stati/optimalnaya-visota-potolka) метра. Заполним с группировкой по расположению квартиры.

# %%
df_flat_propf['ceiling_height'] =df_flat_propf['ceiling_height'].fillna(df_flat_propf
                                                                        .groupby('locality_name')['ceiling_height']
                                                                        .transform('median'))
display(df_flat_propf.head())
# Рассмотрим коэффициент Стьюдента,он стал 0,988, что входит в доверительный интервал погрешностей. Оставляем так.
df_flat_propf['ceiling_height'].describe()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000       108.0           2019-03-07      3
# 1             7       3.350        40.4           2018-12-04      1
# 2            10       5.196        56.0           2015-08-20      2
# 3             0      64.900       159.0           2015-07-24      3
# 4             2      10.000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1            2.63          11.0         18.6      1          NaN   False
# 2            2.70           5.0         34.3      4          NaN   False
# 3            2.70          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  city_centers_nearest  \
# ...

# %%
ax = df_flat_propf.sort_values('ceiling_height').plot(x = 'last_price',
                                                 y = 'ceiling_height',
                                                 title = 'График распределения по высоте потолков',
                                                 kind = 'scatter', 
                                                 ylim = (0, 150),
                                                 xlim = (0,100),
                                                 figsize = (10,5));
ax.set_xlabel('Последняя цена, млн')
ax.set_ylabel('Высота потолков,кв.м.');

# %% [markdown]
# Небольшое количество значений сильно изменяет график распределения по оси абсцисс. Стоит посмотреть,сколько значений приходится на высоту потолков выше 5 метров. Так же не вижу смысла оставлять данные со значениями ниже 2.4, как минимально допустимые.

# %%
print(df_flat_propf[df_flat_propf['ceiling_height'] > 4]['last_price'].count())
df_flat_propf[df_flat_propf['ceiling_height'] < 2.4]['last_price'].count()
# Out:
# 66
# 21

# %% [markdown]
# Заменим значения медианные по группе и откинем значения выше 4 метров и ниже 2.4.

# %%
# Сначала заполним характерными значенями для групп
df_flat_propf['ceiling_height'] =df_flat_propf['ceiling_height'].fillna(df_flat_propf
                                                                        .groupby('locality_name')['ceiling_height']
                                                                        .transform('median'))
#Отфильтруем значения по высоте
df_flat_propf_2 = df_flat_propf.query('(ceiling_height <4) & (ceiling_height >2.4)')
ax = df_flat_propf_2.sort_values('ceiling_height').plot(x = 'last_price',
                                                   y = 'ceiling_height',
                                                   title = 'График распределения по высоте потолков',
                                                   kind = 'scatter', 
                                                   ylim = (2.25, 4.25),
                                                   xlim = (0,100),
                                                   figsize = (10,5))
ax.set_xlabel('Последняя цена, млн')
ax.set_ylabel('Высота потолков,кв.м.');

# %% [markdown]
# #### 'floors_total'

# %% [markdown]
# Теперь займёмся колонкой *'floors_total'*, заполним пропуски и переведем все в целочисленный вид,а так же посмотрим,сколько у нас нулевых значений

# %%
df_flat_propf_2['floors_total'] = df_flat_propf_2['floors_total'].fillna(df_flat_propf_2
                                                                        .groupby('locality_name')['floors_total']
                                                                        .transform('median'))


display(df_flat_propf_2['floors_total'].describe())
display(df_flat_propf_2.head())
display(df_flat_propf_2['floors_total'].unique())

# осталось одно значение без заполнения, посмотрим его.
display(df_flat_propf_2[df_flat_propf_2['floors_total'].isna() == True])

#Значение со слишком многими пропущенными параметрами и единственное, без зазрения совести удаляем
#df_flat_propf_2 = df_flat_propf_2.drop(index=[8986]).reset_index(drop = True)
df_flat_propf_2['floors_total'] = df_flat_propf_2['floors_total'].astype(int)
# Out:
# count    23160.000000
# mean        10.772560
# std          6.592011
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000       108.0           2019-03-07      3
# 1             7       3.350        40.4           2018-12-04      1
# 2            10       5.196        56.0           2015-08-20      2
# 3             0      64.900       159.0           2015-07-24      3
# 4             2      10.000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1            2.63          11.0         18.6      1          NaN   False
# 2            2.70           5.0         34.3      4          NaN   False
# ...

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Медиана может быть равна 9, а квартира при этом будет продаваться на 12 этаже. Тут надо аккуратнее.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Не обратил внимания на это изначально. Сложно подстраивать по другим параметрам и не особо обоснованно,просто отфильтровал эти значения далее исходя из условия,так как их мало. </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Да, критичного тут ничего нет, все равно в категорию других этажей попадут. Но надо быть аккуратнее все равно :)
# </div>

# %%
# КОД РЕВЬЮЕРА

df_flat_propf_2[df_flat_propf_2.floor > df_flat_propf_2['floors_total']]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 457               4    9.788348       70.80           2015-08-01      2
# 2392              7    5.395770       53.00           2017-06-29      2
# 2846              4    2.325000       27.80           2016-09-21      1
# 4617              4    4.275062       61.20           2017-04-27      2
# 4848             15   13.000000       98.00           2017-02-08      3
# 5146             10    3.085024       33.33           2018-10-06      1
# 5784              4    4.262941       59.90           2017-04-02      2
# 5958              1    3.200000       30.30           2018-09-07      0
# 6030              3   10.900000      116.23           2017-05-05      4
# 7922              3    5.426412       50.11           2016-06-08      2
# 8478             19   13.500000       77.80           2019-04-17      2
# 10013             4    4.558637       64.40           2016-09-21      2
# ...

# %%
df_flat_propf_2.query('floor <= floors_total')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20      13.000      108.00           2019-03-07      3
# 1                 7       3.350       40.40           2018-12-04      1
# 2                10       5.196       56.00           2015-08-20      2
# 3                 0      64.900      159.00           2015-07-24      3
# 4                 2      10.000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23693             9       4.600       62.40           2016-08-05      3
# 23694             9       9.700      133.81           2017-03-21      3
# 23695            14       3.100       59.00           2018-01-15      3
# 23697            13      11.475       76.75           2017-03-28      2
# 23698             4       1.350       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# #### 'balcony'

# %% [markdown]
# Если есть пропущенные значения для балкона, наиболее вероятно,что его просто нет.
#
# Заменяем пропущенные значения на ноль.

# %%
df_flat_propf_2['balcony'] = df_flat_propf_2['balcony'].fillna(0)
display(df_flat_propf_2['balcony'].value_counts())
df_flat_propf_2['balcony'].hist(bins = 6);
# Out:
# 0.0    14895
# 1.0     4093
# 2.0     3620
# 5.0      296
# 4.0      179
# 3.0       77
# Name: balcony, dtype: int64

# %% [markdown]
# Максимальное значение - 4. Это квадратура балкона. Заменим на целочисленные.

# %%
df_flat_propf_2['balcony'] = df_flat_propf_2['balcony'].astype(int)

# %% [markdown]
# #### 'kitchen_area'

# %%
# Замениим пропущенные значения на средние по расположению и числу комнат
df_flat_propf_2['kitchen_area'] = df_flat_propf_2['kitchen_area'].fillna(df_flat_propf_2
                                                                        .groupby(['locality_name','rooms'])['kitchen_area']
                                                                        .transform('median'))
display(df_flat_propf_2.head())
df_flat_propf_2['kitchen_area'].isna().sum()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000       108.0           2019-03-07      3
# 1             7       3.350        40.4           2018-12-04      1
# 2            10       5.196        56.0           2015-08-20      2
# 3             0      64.900       159.0           2015-07-24      3
# 4             2      10.000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70            16         51.0      8          NaN   False
# 1            2.63            11         18.6      1          NaN   False
# 2            2.70             5         34.3      4          NaN   False
# 3            2.70            14          NaN      9          NaN   False
# 4            3.03            14         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  city_centers_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Хорошая идея с группировкой по комнатам. Можно также взять отношение кухни к общей площади.
# </div>

# %% [markdown]
# Осталось 253 значения, которые не получилось заполнить таким образом. Попробуем другой метод для оставшихся значений.

# %%
df_flat_propf_2['kitchen_area'] =(
df_flat_propf_2['kitchen_area'].fillna(df_flat_propf_2
                                       .groupby('locality_name')['kitchen_area']
                                       .transform('median'))
)
df_flat_propf_2['kitchen_area'].isna().sum()
# Out:
# 7

# %% [markdown]
# Уже лучше, остальное заполним без группировки общей медианой по столбцу

# %%
df_flat_propf_2['kitchen_area']=(
df_flat_propf_2['kitchen_area'].fillna(df_flat_propf_2['kitchen_area'].median())
)
df_flat_propf_2['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропущенных значений не осталось, идём дальше.

# %% [markdown]
# #### 'living_area'

# %% [markdown]
# В данном столбце значения будем заполнять арифметически. Логично предположить, что жилая площадь квартиры будет считаться вычитанием из общей квадратуры площади балкона и кухни.

# %%
df_flat_propf_2['living_area'] = df_flat_propf_2['total_area'] - df_flat_propf_2['balcony'] - df_flat_propf_2['kitchen_area']
df_flat_propf_2['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Балконы в общую не входят вроде. Тут тоже ведь можно сгруппировать по комнатам. При желании вычислять площадь можно через коэфф-т отношения к общей в этой же самой группировке.
# </div>

# %% [markdown]
# Все значения заполнены. Пропусков нет.

# %% [markdown]
# #### 'floor'

# %%
display(df_flat_propf_2['floor'].isna().sum())
df_flat_propf_2['floor'].unique()
# Out:
# 0
# array([ 8,  1,  4,  9, 13,  5,  6, 22, 26,  7,  3,  2, 11, 15, 18, 10, 19,
#        16, 20, 27, 25, 17, 14, 12, 21, 28, 24, 23, 30, 29, 32, 33, 31])

# %% [markdown]
# Пропусков и нулевых значений нет, отлично. Теперь заменим на условные обозначения "первый","последний" и "другой" наименования этажей.

# %%
def apartment_floor (df_flat_propf_2):
    if df_flat_propf_2['floor'] == 1:
        return 'первый'
    if (df_flat_propf_2['floor'] == df_flat_propf_2['floors_total'])|(df_flat_propf_2['floors_total'] ==1):
        return 'последний'
    return 'другой'
df_flat_propf_2['apartment_floor'] = df_flat_propf_2.apply(apartment_floor,axis = 1)

# %%
df_flat_propf_2['apartment_floor'].unique()
# Out:
# array(['другой', 'первый', 'последний'], dtype=object)

# %% [markdown]
# Отлично,теперь гистограмма.

# %%
sns.barplot(data = df_flat_propf_2,
            x = 'apartment_floor',
            y = 'floors_total');

# %% [markdown]
# Ожидаемо, больше всего предложений квартир,располагающихся не на первом и последнем этаже. На первом и последнем так же ожидаемо предложений примерно поровну.

# %% [markdown]
# #### 'is_apartment'

# %%
print(df_flat_propf_2['is_apartment'].unique())
print(df_flat_propf_2['is_apartment'].value_counts())
print(df_flat_propf_2['is_apartment'].isna().sum())


def apartment (is_apartment):
    if is_apartment == True:
        return 'апартаменты'
    if is_apartment == False:
        return 'квартира'
    else:
        return 'неизвестно'
df_flat_propf_2['is_apartment'] =  df_flat_propf_2['is_apartment'].apply(apartment)
df_flat_propf_2['is_apartment'].value_counts()
# Out:
# [nan False True]
# False    2656
# True       43
# Name: is_apartment, dtype: int64
# 20461
# неизвестно     20461
# квартира        2656
# апартаменты       43
# Name: is_apartment, dtype: int64

# %% [markdown]
# В целом это сделано скорее для красоты отображения,нежели из практиечских соображений. Так как данные этого столбца являются юридическим статусом помещения, восстановление данных не представляется возможным без обращения к тем, кто создавал этот датасет. Таким образом, оставим так.

# %% [markdown]
# #### 'studio'

# %% [markdown]
# Опять же,заменим буллевы данные по логике схожей с заменой значений предыдущего столбца.

# %%
display(df_flat_propf_2['studio'].value_counts())
def is_studio (studio):
    if studio == True:
        return 'студия'
    else:
        return 'комнатная'
df_flat_propf_2['studio'] =  df_flat_propf_2['studio'].apply(is_studio)
df_flat_propf_2['studio'].unique()
# Out:
# False    23013
# True       147
# Name: studio, dtype: int64
# array(['комнатная', 'студия'], dtype=object)

# %% [markdown]
# #### 'open_plan'

# %%
def is_open_plan (open_plan):
    if open_plan == True:
        return 'да'
    else:
        return 'нет'
df_flat_propf_2['open_plan'] =  df_flat_propf_2['open_plan'].apply(is_open_plan)
display(df_flat_propf_2['open_plan'].isna().sum())
df_flat_propf_2['open_plan'].unique()
# Out:
# 0
# array(['нет', 'да'], dtype=object)

# %% [markdown]
# Значения заменены.

# %% [markdown]
# #### 'locality_name'

# %% [markdown]
# Изменим регистр на нижний в колонке *'locality_name'*

# %%
df_flat_propf_2['locality_name'] = df_flat_propf_2['locality_name'].str.lower()

display(df_flat_propf_2['locality_name'].isna().sum())
# Тут встречаются пропуски в значениях,восстановить их адекватно не представляется возможным. Поэтому отбросим их.
# Воспользуемся маленькой хитростью - в метод .query() передадим условие тождественности значения самому себе. Как известно,
# в библиотеках pandas и numpy NaN не равен сам себе
df_flat_propf_2 = df_flat_propf_2.query('locality_name == locality_name')
# Посмотрим, что получилось
df_flat_propf_2['locality_name'].isna().sum()
# Out:
# 13
# 0

# %% [markdown]
# Отлично, тут с пропущенными значениями тоже разобрались.

# %% [markdown]
# #### 'city_centers_nearest'

# %%
df_flat_propf_2['city_centers_nearest'] = df_flat_propf_2['city_centers_nearest']/1000
df_flat_propf_2.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000      108.00           2019-03-07      3
# 1             7       3.350       40.40           2018-12-04      1
# 2            10       5.196       56.00           2015-08-20      2
# 3             0      64.900      159.00           2015-07-24      3
# 4             2      10.000      100.00           2018-06-19      2
# 5            10       2.890       30.40           2018-09-10      1
# 6             6       3.700       37.30           2017-11-02      1
# 7             5       7.915       71.60           2019-04-18      2
# 8            20       2.900       33.16           2018-05-23      1
# 9            18       5.400       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment     studio  \
# 0            2.70            16        83.00      8   неизвестно  комнатная
# ...

# %%
print(df_flat_propf_2['city_centers_nearest'].isna().sum())
print(df_flat_propf_2['city_centers_nearest'].describe())
df_flat_propf_2['city_centers_nearest'].hist(bins =100,figsize = (12,9));
# Out:
# 5346
# count    17801.000000
# mean        14.309038
# std          8.573556
# min          0.181000
# 25%          9.488000
# 50%         13.171000
# 75%         16.333000
# max         65.968000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# В целом распределение выглядит нормально. Ожидаемо, большинство квартир продается на расстоянии 10-20 км от центра. Скорее всего это новые масштабные застройки (жилые массивы) по краям городов, несколько удаленные от центра. Так же встречается рост количества предложений на расстоянии примерно 30 км от центра. Скорее всего там расположен жилой массив-спутник основного города,такого как Москва или Питер.

# %%
ax = df_flat_propf_2.sort_values('last_price').plot(x = 'last_price',
                                               y = 'city_centers_nearest',
                                               xlim = (0,40),
                                               ylim = (0,37),
                                               kind='scatter', 
                                               figsize=(8, 6), 
                                               grid = True,
                                               alpha = 0.1,
                                               title = ('Цена в зависимости от удаленности центра'))
ax.set_xlabel('Последняя цена, млн')
ax.set_ylabel('Высота потолков,кв.м.');

# %% [markdown]
# Как мы видим, от выбросов мы избавились.

# %% [markdown]
# #### 'days_exposition'

# %%
print(df_flat_propf_2['days_exposition'].describe())
df_flat_propf_2['days_exposition'].isna().sum()
df_flat_propf_2['days_exposition'] = df_flat_propf_2['days_exposition'].fillna(-1)
df_flat_propf_2['days_exposition'] = df_flat_propf_2['days_exposition'].astype(int)
display(df_flat_propf_2.head())
df_flat_propf_2['days_exposition'].plot(kind = 'box',grid = True, figsize = (13,9));
# Out:
# count    20081.000000
# mean       179.703501
# std        218.694286
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        229.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20      13.000       108.0           2019-03-07      3
# 1             7       3.350        40.4           2018-12-04      1
# 2            10       5.196        56.0           2015-08-20      2
# 3             0      64.900       159.0           2015-07-24      3
# 4             2      10.000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment     studio  \
# 0            2.70            16         83.0      8   неизвестно  комнатная
# 1            2.63            11         27.4      1   неизвестно  комнатная
# 2            2.70             5         47.7      4   неизвестно  комнатная
# ...

# %% [markdown]
# Видим довольно большое количество объявлений выходящих за 3 квадриль. Более 400 дней. Скорее всего это связано не с конкретными параметрами квартиры, а с ее состоянием. Отфильтруем их.

# %%
df_flat_med_sale = df_flat_propf_2.query('days_exposition<260')
df_flat_med_sale ['days_exposition'].plot(kind = 'box',grid = True, figsize = (13,9));

# %% [markdown]
# Видим, что в среднем продажа квартиры занимает от 20 до 110 дней. Медиана по дням до продажи находится на отметке в 50 дней.
#
# Соответственно, быстрой продажой можно считать до 20 дней, долгой - больше 110 дней.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Соглашусь.
# </div>

# %%
#df_flat_med_sale ['days_exposition'].hist(bins =50, grid = True,figsize = (12,8));
ax = df_flat_med_sale ['days_exposition'].plot(kind = 'hist',
                                              bins =50, 
                                              grid = True,
                                              figsize = (12,8),
                                              title = ('Скорость покупки в днях'))
ax.set_xlabel('Дни с момента выставления')
ax.set_ylabel('Частота');

# %% [markdown]
# Что за пик при значении -1 - это понятно,что пропущенные значения. Смущают три других пика,рассмотрим их поближе.

# %%
df_flat_med_sale1 = df_flat_med_sale.query('40<= days_exposition <=100')

ax = df_flat_med_sale1['days_exposition'].plot (kind = 'hist',
                                                bins=61,
                                                figsize = (14,8),
                                                title = ('Анализ аномалий в днях выставления'))
ax.set_xlabel('Дни с момента выставления')
ax.set_ylabel('Частота');

# %% [markdown]
# Видны резкие пики при значениях 45,60 и 90. Скорее всего это переразмещенные объявления с изменившейся ценой, автоматически предлагаемые системой замены с уменьшением цены, на которые согласились люди. Такие значения лучше будет не учитывать в выборке.Так же судя по распределению,пропущенные значения скорее всего являются выбросами и их мы тоже исключим.

# %%
df_flat_med_sale = df_flat_med_sale.query('(days_exposition != 45)& \
                                          (days_exposition != 60)& \
                                          (days_exposition != 90)& \
                                          (days_exposition != -1)')

df_flat_med_sale.reset_index(drop = True)
df_flat_med_sale.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7        3.35       40.40           2018-12-04      1
# 4             2       10.00      100.00           2018-06-19      2
# 5            10        2.89       30.40           2018-09-10      1
# 6             6        3.70       37.30           2017-11-02      1
# 8            20        2.90       33.16           2018-05-23      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment     studio  \
# 1            2.63            11        27.40      1   неизвестно  комнатная
# 4            3.03            14        59.00     13   неизвестно  комнатная
# 5            2.60            12        21.30      5   неизвестно  комнатная
# 6            2.64            26        21.90      6   неизвестно  комнатная
# 8            2.70            27        24.35     26   неизвестно  комнатная
#
#   open_plan  kitchen_area  balcony              locality_name  \
# ...

# %% [markdown]
# ### Столбцы с географическими особенностями

# %% [markdown]
# Данные были получены автоматически, в дальнейшем мы их не используем, так что эти столбцы оставим без изменений.

# %% [markdown]
# ### Выводы

# %% [markdown]
# - столбец *'total_images'* оставили без изменений;
# - в столбце *'last_price'* пропусков нет, изменили размерность на миллионы для удобства;
# - *'total_area'*,пропусков нет, отсеяли нерелевантные значения;
# - *'first_day_exposion'* привели в нормальный формат вермени;
# - в *'rooms'* пропусков нет, отсеяли выбросы;
# - в *'ceiling_height'* восстановили пропуски по медиане групп, отсеяли нерелевантные варианты;
# - *'floors_total'* так же заполнили по медиане групп,отсеяли выбросы;
# - заменили значения *'balcony'* на целочисленные, пропусков и выбросов не обнаружено;
# - *'kitchen_area'* отсеяли выбросы и заполнили по медиане группы;
# - пропущенные значения в столбце *'living_area'* заполнили логически исходя из предыдущих;
# -  поменяли значения в *'floor'* на "первый", "последний" и "другой";
# -  буллевы значения *'is_apartment'* заменили на "апартаменты" и "квартира";
# -  в столбце *'studio'* сделали аналогично предыдущему,заменив на "студия" и "комнатная";
# -  аналогично в *'open_plan'* на "да" и "нет";
# - в *'locality_name'* пропуски удалены, приведено к нижнему регистру;
# - *'city_centers_nearest'* - значения переведены в километры,отброшены выбросы;
# - *'days_exposition'* отброшены выбросы.
#
# Все релевантные исследованию данные заполнены и скорректированы.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Отличная работа.
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Создадим новый датафрейм с двумя столбцами, которые нам понадобятся в дальнешей исследовании и будет пошагово рассчитывать
# и добавлять остальные исходя из данных отфильтрованного на прошлом шаге датафрейма.

# %%
df_new = pd.DataFrame(data = df_flat_med_sale, columns = ['last_price',
                                                          'apartment_floor',
                                                          'total_area','rooms',
                                                          'city_centers_nearest',
                                                          'locality_name','ceiling_height'])

# %% [markdown]
# Сначала добавим столбец со значениями цены за квадратный метр.

# %%
df_new['sq_m_price'] = ((df_flat_med_sale['last_price']*1_000_000)/df_flat_med_sale['total_area']).astype(int)
df_new['last_price'] = (df_new['last_price']*1_000_000).astype(int)
display(df_new.head())
display(df_new['sq_m_price'].describe())
# Out:
#    last_price apartment_floor  total_area  rooms  city_centers_nearest  \
# 1     3350000          первый       40.40      1                18.603
# 4    10000000          другой      100.00      2                 8.098
# 5     2890000          другой       30.40      1                   NaN
# 6     3700000          другой       37.30      1                19.143
# 8     2900000          другой       33.16      1                   NaN
#
#                locality_name  ceiling_height  sq_m_price
# 1             посёлок шушары            2.63       82920
# 4            санкт-петербург            3.03      100000
# 5  городской посёлок янино-1            2.60       95065
# 6          посёлок парголово            2.64       99195
# 8             посёлок мурино            2.70       87454
# count     14048.000000
# mean      97130.011959
# std       36411.555559
# min         111.000000
# 25%       78082.750000
# 50%       94677.000000
# 75%      111782.000000
# max      640422.000000
# ...

# %% [markdown]
# Видим некоторе количество выбросов по цене за квадратный метр. Посмотрим "ящик с усами"

# %%
ax = df_new['sq_m_price'].plot(kind = 'box',
                               figsize = (5,12),
                               title = ('Распределение цен за кв.м.'))
ax.set_ylabel('Цена за кв.м.');

# %% [markdown]
# Отфильтруем редкие значения вышe 300 и менее 30 т.р. за квадратный метр.

# %%
df_new = df_new.query('30_000 < sq_m_price < 300_000')

# %% [markdown]
# Методом **.dt.weekday** добавим столбец, исходя из данных столбца *'first_day_exposition'* оригинального датафрейма.

# %%
df_new['week_day'] =df_flat_med_sale['first_day_exposition'].dt.weekday
#Напишем функцию для перевода численного вида в обычные дни недели текстового вида
def week_text (week_day):
    days = ['понедельник','вторник','среда',
            'четверг','пятница','суббота','воскресенье']
    return days[week_day]
#Заменим оба датафрейма, основной - в виде строк для хранения, второй - для красивого отображения графиков
df_new['week_day'] = df_new['week_day'].apply(week_text)

df_new.head(15)
# Out:
#     last_price apartment_floor  total_area  rooms  city_centers_nearest  \
# 1      3350000          первый       40.40      1                18.603
# 4     10000000          другой      100.00      2                 8.098
# 5      2890000          другой       30.40      1                   NaN
# 6      3700000          другой       37.30      1                19.143
# 8      2900000          другой       33.16      1                   NaN
# 10     5050000          другой       39.60      1                13.878
# 11     3300000          другой       44.00      2                51.677
# 14     4400000          первый       36.00      1                30.759
# 15     4650000          другой       39.00      1                14.259
# 18     3250000          другой       31.00      1                10.842
# 19    14200000          другой      121.00      3                12.843
# 20     6120000          другой       80.00      3                19.311
# ...

# %%
#df_new_days = df_new.sort_values(by = 'week_day', ascending = True).reset_index()
# func
#df_new_days['week_day'] = df_new_days['week_day'].apply(week_text)
#df_new_days['week_day'].unique()

# %% [markdown]
# То же самое сделаем и для месяцев методом **dt.month**.

# %%
df_new['month'] =df_flat_med_sale['first_day_exposition'].dt.month
# Так же как и с днями, отсортируем месяцы
df_new = df_new.sort_values(by = 'month', ascending = True)
# Создадим функцию для подсчета месяца исходя из совпадения номера месяца и индекса в списке months
def month_text_c(month):
    months = ['январь','февраль', 
              'март', 'апрель', 'май',
              'июнь', 'июль','август', 
              'сентябрь', 'октябрь', 'ноябрь', 
              'декабрь']
    return months[month-1]
df_new['month'] = df_new['month'].apply(month_text_c)
display(df_new['month'].unique())
# Out:
# array(['январь', 'февраль', 'март', 'апрель', 'май', 'июнь', 'июль',
#        'август', 'сентябрь', 'октябрь', 'ноябрь', 'декабрь'], dtype=object)

# %% [markdown]
# А теперь для года, при помощи **dt.year**

# %%
df_new['year'] =df_flat_med_sale['first_day_exposition'].dt.year

# %% [markdown]
# Соотношение жилой площади к общей рассчитаем простым делением значением соответствующих столбцов исходного датафрейма.

# %%
df_new['live_s/all_s'] =df_flat_med_sale['living_area']/df_flat_med_sale['total_area']
df_new['live_s/all_s'].describe()
# Out:
# count    13793.000000
# mean         0.792340
# std          0.081397
# min          0.212121
# 25%          0.742857
# 50%          0.808741
# 75%          0.852459
# max          0.974619
# Name: live_s/all_s, dtype: float64

# %% [markdown]
# То же самое сделаем и для соотношения размеров кухни к общей площади.

# %%
df_new['kitchen_s/all_s'] =df_flat_med_sale['kitchen_area']/df_flat_med_sale['total_area']
df_new['kitchen_s/all_s'].describe()
# Out:
# count    13793.000000
# mean         0.195355
# std          0.076401
# min          0.025381
# 25%          0.138983
# 50%          0.180180
# 75%          0.241379
# max          0.787879
# Name: kitchen_s/all_s, dtype: float64

# %%
df_new = df_new.reset_index(drop = True)
df_new.head()
# Out:
#    last_price apartment_floor  total_area  rooms  city_centers_nearest  \
# 0     3149000          другой       46.50      1                   NaN
# 1     4550000          другой       42.00      1                11.184
# 2     5915000          другой       62.91      2                16.002
# 3     3960000          другой       40.10      1                18.783
# 4     9000000          другой       45.10      1                 4.263
#
#        locality_name  ceiling_height  sq_m_price     week_day   month  year  \
# 0          сертолово            2.75       67720      пятница  январь  2017
# 1    санкт-петербург            2.75      108333      суббота  январь  2018
# 2    санкт-петербург            2.70       94023  понедельник  январь  2018
# 3  посёлок парголово            2.64       98753  понедельник  январь  2018
# 4    санкт-петербург            2.70      199556  понедельник  январь  2018
#
#    live_s/all_s  kitchen_s/all_s
# 0      0.774194         0.225806
# ...

# %% [markdown]
# Таким образом, была сформирована новая таблица,готовая для дальнейшего исследования.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Крайне сложно будет сравнивать параметры продажи в зависимости от стоимостей

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Мы скорее ищем зависимость стоимости от параметров.
#
#
#
# На всякий случай проверим себя:
# </div>

# %%
# КОД РЕВЬЮЕРА

df_new[['last_price', 'total_area','rooms', 'ceiling_height' ]].describe().loc[['min', 'max']]
# Out:
#      last_price  total_area  rooms  ceiling_height
# min    920000.0        12.0    0.0            2.45
# max  46950000.0       199.2    7.0            3.98

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Да, все отлично. </div>

# %% [markdown]
# ### Зависимость цены за кв.м. от дня недели

# %%
ax = df_new.pivot_table(index = 'week_day',
                        values = 'sq_m_price',
                        aggfunc = 'median').plot(kind='bar',
                                                 ylim = (90_000,102_000),
                                                 grid = True,
                                                 figsize = (7,10),
                                                 legend = None,
                                                 title = ('Зависимость цены продажи от дня'))
ax.set_xlabel('День недели')
ax.set_ylabel('Цена за кв.м.');

# %%
df_new['week_day1'] =df_flat_med_sale['first_day_exposition'].dt.weekday
ax = df_new.pivot_table(index = 'week_day1',
                        values = 'sq_m_price').plot(kind='line',
                                                 #ylim = (95_000,105_000),
                                                 grid = True,
                                                 figsize = (7,10),
                                                 legend = None,
                                                 title = ('Зависимость цены продажи от дня'))
ax.set_xlabel('День недели')
ax.set_ylabel('Цена за кв.м.');

# %% [markdown]
# #### Вывод

# %% [markdown]
# Как мы видим,в воскресенье и вторник квартиры продавались по чуть более низкой цене,однако разброс даныых крайне малый, скорее даже несущественный и бОльший размер выборки выровнял бы эти зависимости ещё сильнее. Касаемо дня недели, делаем вывод, что он **слабо влияет на цену квартиры**. Однако, есть небольшое увеличение цены за кв.м. в понедельник и вторник. Это может быть связано с открытием биржи и изменением курса валюты, если например квартира продается в долларах или евро.

# %% [markdown]
# Здесь наблюдаются небольшие колебания, но больше похоже на "шум", нежели на какую-то логичную и взаимосвязанную структуру.

# %% [markdown]
# ### Зависимость цены за кв.м. от месяца

# %%
df_new['month1'] =df_flat_med_sale['first_day_exposition'].dt.month
ax = df_new.pivot_table(index = 'month1',
                   values = 'sq_m_price').plot(kind='bar',
                                               ylim = (90_000,105_000),
                                               grid = True,
                                               figsize = (7,9),
                                               legend = None,
                                               title = ('Зависимость цены продажи от месяца'))
ax.set_xlabel('Месяц')
ax.set_ylabel('Цена за кв.м.');

# %% [markdown]
# #### Вывод

# %% [markdown]
# Как мы видим, самые высокие цены у объявлений, которые были выставлены в августе и сентябре. Скорее всего это связано с сезоном отпусков, так как после возвращения люди, продающие квартиру, либо снижают,либо увеличивают стоимость своей квартиры, а так же чаще выставляют их на продажу,спрос на покупку после сезона отпусков растет - с ним растут и цены на квадратный метр. Так же видим небольшое падение в стоимости недвижимости в апреле,мае и октябре. Первые два месяца можно объяснить стартом дачного сезона, так как люди стараются как можно быстрее продать квартиру,так как и покупатели и продавцы могут не хотеть надолго задерживаться в городе и снижают цену с одной стороны и ухудшается спрос с другой.
#
# В 2018 г. в октябре сильно упал [индекс стоимости жилья в долларах](https://www.irn.ru/gd/za-5-let-po-godam-v-dollarah/#begin). Скорее всего это и оказало влияние на небольшой провал в цене за кв.м.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ✔️</b>
#
# Здорово, что используешь внешние истонички информации.</div>

# %% [markdown]
# ### Зависимость цены за кв.м.  от года

# %%
ax = df_new.pivot_table(index = 'year',
                   values = 'sq_m_price',
                   aggfunc = 'median').plot(kind='bar',
                                            ylim = (80_000,115_000),
                                            grid = True,
                                            legend = False,
                                            figsize = (7,9),
                                            title = ('Зависимость цены за кв.м. в зависимости от года публикации'))
ax.set_xlabel('Год')
ax.set_ylabel('Цена за кв.м.');

# %% [markdown]
# #### Вывод

# %% [markdown]
# Опять же,в целом логичный факт, обоснованный экономической ситуацией. С ростом инфляции и развитием рынка недвижимости, а так же ростом численности населения городов в результате продолжающихся процессов урбанизации, цена за квадратный метр будет постепенно увеличиваться с каждый годом, что мы и видим на представленном графике.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ✔️</b>
#
# Думаю, картина с месяцем и днем недели тянет на случайность. Ведь речь идет о дате размещения и о цене продажи. Разместить можно во вторник в мае, а продать в пятницу в ноябре, по более низкой цене. Это можно даже проверить, построив точно такие же графики для разных лет. Наверняка ситуация будет меняться. Хотя летом люди чаще думают об отпуске, чем о покупке квартиры, так что тут может быть связь. А вот год - да, вполне может влиять. Из года в год экономическая ситуация меняется, а вместе с ней и покупательская способность.
# </div>

# %% [markdown]
# ### Зависимость цены за кв.м от этажа квартиры

# %%
df_new.pivot_table(index = 'apartment_floor',
                   values = 'sq_m_price',
                   aggfunc = 'mean').plot(kind='bar',
                                          ylim = (80_000,110_000),
                                          legend = False,
                                          grid = True,
                                          figsize = (7,9),
                                          title = ('Зависимость цены за кв.м от этажа квартиры'))
ax.set_xlabel('Этаж')
ax.set_ylabel('Цена за кв.м.');

# %% [markdown]
# #### Вывод

# %% [markdown]
# Самая высокая цена за квадратный метр у квартир, расположенных между первым и последним этажом.
#
# На первом этаже бывает довольно шумно, грязно. Некоторые люди переживают, что может быть небезопасно. Так же вид из окна зачастую оставляет желать лучшего, из-за чего цена за квадратный метр у таких квартир ниже других.
#
# Так же часто в домах старого фонда бывают проблемы с крышей, она может протекать и в случае какой-либо поломки, например, лифта - это может быть крайне неудобным и является скорее негативным фактором при выборе квартиры.

# %% [markdown]
# ### Зависимость цены за кв.м. от площади квартиры

# %%
df_new.head()
df_new['total_area'].describe()
#sq_m = [20,30,40,50,60,70,80,90,100,125,150,175,123]
def group_flat(total_area):
    if total_area <= 20:
        return 20
    if total_area <= 30:
        return 30
    if total_area <= 40:
         return 40
    if total_area <= 50:
        return 50
    if total_area <= 60:
        return 60
    if total_area <= 80:
        return 80
    if total_area <= 100:
        return 100
    if total_area <= 125:
        return 125
    if total_area <= 150:
        return 150
    if total_area <= 175:
        return 175
    if total_area <= 200:
        return 200
    #for i in range(len(sq_m)):
        #if total_area <= sq_m[i]:
            #total_area = sq_m[i]
        #else:
            #i+1
    #return total_area
    
df_new['total_area_grouped'] = df_new['total_area'].apply(group_flat)
display(df_new.head())
df_new['total_area_grouped'].unique()
# Out:
#    last_price apartment_floor  total_area  rooms  city_centers_nearest  \
# 0     3149000          другой       46.50      1                   NaN
# 1     4550000          другой       42.00      1                11.184
# 2     5915000          другой       62.91      2                16.002
# 3     3960000          другой       40.10      1                18.783
# 4     9000000          другой       45.10      1                 4.263
#
#        locality_name  ceiling_height  sq_m_price     week_day   month  year  \
# 0          сертолово            2.75       67720      пятница  январь  2017
# 1    санкт-петербург            2.75      108333      суббота  январь  2018
# 2    санкт-петербург            2.70       94023  понедельник  январь  2018
# 3  посёлок парголово            2.64       98753  понедельник  январь  2018
# 4    санкт-петербург            2.70      199556  понедельник  январь  2018
#
#    live_s/all_s  kitchen_s/all_s  week_day1  month1  total_area_grouped
# ...

# %%
ax = df_new.pivot_table(index ='total_area_grouped',
                        values = 'sq_m_price',
                        aggfunc = 'mean').plot(kind = 'bar',
                                               grid = True,
                                          #xlabel = 'Площадь квартиры в кв.м., до',
                                               legend = False,
                                               figsize = (10,7),
                                               title = ('Зависимость цены за кв.м. от площади квартиры'))
ax.set_xlabel('Площадь квартиры в кв.м, до')
ax.set_ylabel('Цена за кв.м, рубли');

# %% [markdown]
# #### Вывод

# %% [markdown]
# Как мы видим в сегменте квартир от 20 кв.м стоимость за квадратный метр уменьшается вплоть до квартир размером 60 кв.м. Такое плавное снижение в стоимости за квадратный метр обусловлено тем, что в среднем ценовом сегменте квартиры действительно обходятся дешевле и самыми дорогими относительно цены кв.м. являются маленькие однушки или студии, так как пользуются огромной популярностью в России,а значит спрос на них крайне высокий. Так как абсолютная цена за квартиру все равно очевидно  ниже нежели более больших по квадратуре вариантов.
#
# Так же стоит отметить что с квартир площадью 80 км.м. с увеличением площади начинает снова расти цена. Это объясняется тем, что такие квартиры относятся к высшим сегментам жилья - '"бизнес-класс", "vip-класс", "премиум-класс"'.
#
# С увеличением площади появляются террасы,большие балконы и прочее, из-за чего цена за кв.м. поднимается.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ✔️</b>
#
# Все логично.</div>

# %% [markdown]
# ### Зависимость цены за кв.м. от числа комнат

# %%
ax = df_new.pivot_table(index = 'rooms',
                        values = 'sq_m_price',
                        aggfunc = 'median').plot(kind = 'bar',
                                               grid = True,
                                               figsize = (10,7),
                                               legend = False,
                                               title = ('Зависимость цены за кв.м. количества комнат'))
ax.set_xlabel('Комнат')
ax.set_ylabel('Цена за кв.м, рубли');

# %%
df_new['last_price_mil'] = df_new['last_price']/1_000_000
ax = df_new.query('last_price_mil<30').pivot_table(index = 'total_area',
                                                   values = 'last_price_mil',
                                                   aggfunc = 'median').plot(kind = 'line',
                                                                            grid = True,
                                                                            figsize = (10,7),
                                                                            legend = False,
                                                                            title = ('Зависимость цены за кв.м. от площади'))
ax.set_xlabel('Площадь,кв.м.')
ax.set_ylabel('Цена квартиры');

# %% [markdown]
# #### Вывод

# %% [markdown]
# Данный график показывает схожую картину с зависимостью от площади. Опять же, студии и небольшие однокомнатные квартиры дешевле в абсолютном выражении. Но из-за высокго спроса у молодежи и людей-одиночек и небольших семей, цена за кв.м будет выше, нежели на более многокомнатую квартиру.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ✔️</b>
#
# Это не гистограмма, а простой график кривой. Дело в том, что значений на оси X очень много, поэтому он получается с шумом. Можно взять точечную. Хотя тенденция и тут отлично видна.</div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Убрал  слово гистограмма.</div>

# %% [markdown]
# ###  Зависимость цены за кв.м. от удаленности от центра

# %% [markdown]
# Для начала сделаем группировку по удаленности функцией с шагом в 10 км.

# %%
def km (city_centers_nearest):
    if city_centers_nearest <= 1:
        return 1
    if city_centers_nearest <= 5:
        return 5
    if city_centers_nearest <= 10:
        return 10
    if city_centers_nearest <= 15:
        return 15
    if city_centers_nearest <= 20:
        return 20
    if city_centers_nearest <= 30:
        return 30
    if city_centers_nearest <= 40:
        return 40
    if city_centers_nearest <= 50:
        return 50
df_new['center_km'] = df_new ['city_centers_nearest'].apply(km)

# %%
ax = df_new.sort_values('center_km').pivot_table(index = 'center_km',
                                                 values = 'sq_m_price',
                                                 aggfunc = 'median').plot(kind = 'line',
                                                 grid = True,
                                                 figsize = (10,7),
                                                 legend = False,
                                                 title = ('Зависимость цены за кв.м. расстояния от центра'))
ax.set_xlabel('Расстояние до центра, км')
ax.set_ylabel('Цена за кв.м, рубли');

# %% [markdown]
# > График показывает гиперболическую зависимость цены за кв.м. от удаленности от центра(*так же свидетельствуя об обратной зависимости этих параметров*)

# %% [markdown]
# #### Вывод

# %% [markdown]
# - В зоне **до 5 километров от центра** цена резко снижается с увеличением расстояния - это элитная недвижимость в самом центре города.
#
# - На графике видна линия, где наблюдается снижение скорости падения цен за кв.м. относительно тренда при расстоянии от центра **от 5 до 10 километров**. Это зона с более малым разбросом в цене за кв.м.  - из чего можно сделать вывод, что до 10 км - зона центра города. Так как после этого значения скорость падения цены за квадратный метр снова увеличивается.
#
# - Так же вплоть до **30 км от центра** - скорее всего это является условной чертой города.
#
# - Далее скорость снижения цены за кв.м. уменьшается вплоть до **40 килметров от центра** - это зона ближайшего пригорода по радиусу.
#
# - После **40 километров от центра** падение цен замедляется ещё больше - это зона деревень, поселков и городов-спутников.

# %% [markdown]
# ### Большая десятка

# %% [markdown]
# Рассмотрим 10 населённых пунктов с наибольшим числом объявлений. Посчитаем среднюю цену квадратного метра в этих населённых пунктах.

# %%
# Взглянем на них
df_new['locality_name'].value_counts().head(11)
# Out:
# санкт-петербург      9498
# посёлок мурино        398
# посёлок шушары        300
# колпино               224
# всеволожск            217
# пушкин                209
# посёлок парголово     205
# деревня кудрово       197
# гатчина               177
# выборг                132
# петергоф              121
# Name: locality_name, dtype: int64

# %% [markdown]
# Посчитаем , среднюю, минимальную и максимальную стоиомсть жилья в данных населенных пунктах.

# %%
df_big_ten= df_new.pivot_table(index = 'locality_name', 
                    values = 'sq_m_price',
                    aggfunc = ['count','mean','max','min'],
                    margins = True).sort_values(('count','sq_m_price'), 
                                                ascending = False).head(11).round({('mean','sq_m_price'):2})
df_big_ten
# Out:
#                        count       mean        max        min
#                   sq_m_price sq_m_price sq_m_price sq_m_price
# locality_name
# All                    13793   97231.88     296610      30136
# санкт-петербург         9498  108141.30     296610      35384
# посёлок мурино           398   86146.41     138580      50000
# посёлок шушары           300   78443.40     147826      47833
# колпино                  224   75062.67     125000      47957
# всеволожск               217   66728.26     133333      40029
# пушкин                   209  100628.35     166666      59836
# посёлок парголово        205   89579.76     138522      48543
# деревня кудрово          197   92635.79     142857      54160
# гатчина                  177   68960.04     105818      45238
# выборг                   132   57858.30      86363      33547

# %% [markdown]
# #### Вывод

# %% [markdown]
# Больщая часть предложений приходится на Санкт-Петербург. Так как он, очевидно, и является центром, от которого ведется отсчёт, средняя цена за квадратный метр в нём наиболее высокая. За ним по средней цене следует Пушкин и Кудрово. Минимальная цена за квадратный метр приходится на Выборг, что связано с его отдаленностью от Санкт-Петербурга. Средняя цена за квадратный метр почти в два раза ниже,чем в Санкт-Петербурге, чуть повыше цена на недвижимость в Всеволжске - 66,7 тыс.рублей.
# Цена на ближайшие районы к городу, таких как Кудрово,Пушкин и Мурино выше тех,что расположены в отдалении от центра.

# %% [markdown]
# ## Санкт - Петербург

# %% [markdown]
# ### Цены/удаленности от центра, поиск центра города

# %% [markdown]
# Для начала выделим из датафрейма квартиры, которые расположены в Санкт - Петербурге

# %%
df_spb = df_new.query('locality_name == "санкт-петербург"')
df_spb.head()
# Out:
#    last_price apartment_floor  total_area  rooms  city_centers_nearest  \
# 1     4550000          другой       42.00      1                11.184
# 2     5915000          другой       62.91      2                16.002
# 4     9000000          другой       45.10      1                 4.263
# 5     3900000          другой       50.00      2                12.921
# 6     3550000       последний       31.00      1                11.396
#
#      locality_name  ceiling_height  sq_m_price     week_day   month  year  \
# 1  санкт-петербург            2.75      108333      суббота  январь  2018
# 2  санкт-петербург            2.70       94023  понедельник  январь  2018
# 4  санкт-петербург            2.70      199556  понедельник  январь  2018
# 5  санкт-петербург            2.55       78000      четверг  январь  2018
# 6  санкт-петербург            2.70      114516      четверг  январь  2018
#
#    live_s/all_s  kitchen_s/all_s  week_day1  month1  total_area_grouped  \
# ...

# %%
df_spb = df_spb.dropna(axis = 0)
df_spb['city_centers_nearest'] = df_spb['city_centers_nearest'].astype(int)
df_spb_pivot = df_spb.pivot_table(index = 'city_centers_nearest',
                                  values = 'sq_m_price',
                                  aggfunc ='mean')
ax = df_spb_pivot.plot(kind = 'line',
                  xlim = (0,25),
                  ylim = (75_000,140_000),
                  figsize = (10,10), 
                  legend = False,
                  grid = True,
                  title = ('Зависимость цены за кв.м. от удаленности центра в Санкт-Петербурге'))
ax.set_xlabel('Расстояние до центра, км')
ax.set_ylabel('Цена за кв.м, рубли')
ax.set_xticks(ticks = range(26));

# %% [markdown]
# > Зависимость в Санкт-Петербурге схожа с общей зависимостью от удаленности по датафрейму. Судя по графику, центрльной зоной Питера можно считать зону протяженностью 3 километров в диаметре от центра. Дальнейший рост цен вплоть до расстояния 8 км от центра появляются более премиальные квартиры с лучшими условиями по самим квартирам,не находящиеся в непосредственной близкости к центру города.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Город не такой большой. 8 км захватит еще 3-4 района, помимо центра. Предлагаю 3 км. Подъем после 3 можно объяснить тем, что тут появляются особые квартиры с большей площадью, например, или с хорошим видом. И это действительно так и есть. Если взять 5-7 км от центра на север, то попадем на очень и очень дорогую недвижимость с чуть ли не лучшим видом в городе. Хотя это не будет центральным районом. Я тебе предлагаю брать меньший радиус, руководствуясь здравым смыслом: диаметр 16 км это как-то многовато.  Как ты считаешь? Понимаю, что формулировка сбивает, но все же :)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Согласен, справделивое замечание.)
#
# Исправил вывод, далее поменяю и размер радиуса при подсчете и визуализации метрик квартир.</div>

# %%
display(df_spb_pivot['sq_m_price'].round(2))
# Out:
# city_centers_nearest
# 0     135095.65
# 1     130300.23
# 2     119619.59
# 3     115362.56
# 4     130805.61
# 5     131016.25
# 6     133651.46
# 7     128019.54
# 8     111555.50
# 9     109363.67
# 10    110151.51
# 11    105322.90
# 12    109492.87
# 13    105767.70
# 14    103299.05
# 15     99738.56
# 16     98290.50
# 17     94240.51
# 18     92322.54
# 19     93735.62
# 20    104081.23
# 21     90464.34
# 22     83055.81
# 23     86858.27
# 24     78109.78
# 25     93361.76
# 26     55118.50
# 27    132115.00
# 28     80018.75
# Name: sq_m_price, dtype: float64

# %% [markdown]
# #### Вывод

# %% [markdown]
# С ростом удаленности от центра цена за квадратный метр падает, встречаются повышения цены, не выбивающиеся в выбросы. Скорее всего это новые элитные жилые комплексы или новостройки, где часто жилье стоит дороже чем в среднем по району.

# %% [markdown]
# ### Анализ квартир в центре

# %% [markdown]
# Для начала отберём квартиры, расположенные в центре Питера

# %%
df_center = df_spb.query('city_centers_nearest<3')
df_center.head()
# Out:
#      last_price apartment_floor  total_area  rooms  city_centers_nearest  \
# 150     7250000       последний        93.0      3                     2
# 216     8418000          другой        91.5      2                     2
# 217     4650000          первый        42.0      2                     1
# 310    15490000          другой       148.0      5                     2
# 323     5650000          первый        55.0      2                     1
#
#        locality_name  ceiling_height  sq_m_price     week_day   month  year  \
# 150  санкт-петербург             3.1       77956      четверг  январь  2019
# 216  санкт-петербург             3.0       92000      вторник  январь  2016
# 217  санкт-петербург             2.7      110714      пятница  январь  2018
# 310  санкт-петербург             2.7      104662      суббота  январь  2018
# 323  санкт-петербург             2.7      102727  понедельник  январь  2018
#
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ❌</b>
#
# Знак :)</div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Да, логично...)
#
# Поменял знак, исправил диаметр, поправил далее графики и выводы к ним.</div>

# %% [markdown]
# #### Анализ площади квартир в центре

# %%
display(df_spb['total_area_grouped'].describe())
ax = df_spb['total_area_grouped'].plot(title = 'График распределения по размеру жилой площади',
                 kind = 'hist',
                 grid = True,
                 bins =9,
                figsize = (10,10))
ax.set_xlabel('Общая площдь,кв.м.')
ax.set_ylabel('Последняя цена, млн');
# Out:
# count    5705.000000
# mean       63.862401
# std        27.429679
# min        20.000000
# 25%        40.000000
# 50%        60.000000
# 75%        80.000000
# max       200.000000
# Name: total_area_grouped, dtype: float64

# %% [markdown]
# >Распределение нормальное, большая часть квартир **до 100 кв.м.** Средняя площадь - **50 - 60 кв.м**. Практически нет квартир меньше 25 кв.м и больше 175. Присутствует довольно большой процент квартир площадью от **75 до 100 кв.м.**

# %% [markdown]
# #### Анализ высоты потолков в центре

# %%
df_center['ceiling_height'].describe()
# Out:
# count    170.000000
# mean       3.037059
# std        0.339032
# min        2.500000
# 25%        2.700000
# 50%        3.000000
# 75%        3.300000
# max        3.800000
# Name: ceiling_height, dtype: float64

# %%
ax = df_center['ceiling_height'].plot(title = 'График распределения по высоте потолков',
                                                  kind = 'hist',
                                                  grid = True,
                                                  legend = False,
                                                  figsize = (10,5))
ax.set_xlabel('Высота потолков,м')
ax.set_ylabel('Частота');

# %% [markdown]
# > Чаще всего встречаются потолки высотой от 2.6 до 2.7 метров. Остальная часть находится в диапазоне от 2.9 до 3.8 м. Это старый жилищный фонд с высокими потолками. Очень хорошо характеризует центр Санкт-Петербурга.

# %% [markdown]
# #### Анализ числа комнат в квартирах центра

# %%
df_center['rooms'].describe()
# Out:
# count    170.000000
# mean       2.835294
# std        1.326534
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        7.000000
# Name: rooms, dtype: float64

# %%
ax = df_center['rooms'].plot(title = 'График распределения по кол-ву комнат',
                                                  kind = 'hist',
                                                  grid = True,
                                                  bins = 7,
                                                  legend = False,
                                                  figsize = (10,5))
ax.set_xlabel('Количество комнат в квартире')
ax.set_ylabel('Частота');

# %% [markdown]
# > В среднем в центре Питера больше всего объявлений по двух и трехкомнатным квартирам. Чуть меньше однокомнатных. Далее по убывающей до четырёхкомнатных. Гораздо реже встреяаются пяти- и шестикомнатные квартиры.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Чуть поменялись распределения.
# </div>

# %% [markdown]
# #### Зависимость цены за кв.м от этажа квартиры

# %%
ax = df_center.pivot_table(index = 'apartment_floor',
                   values = 'sq_m_price',
                   aggfunc = 'mean').plot(kind='bar',
                                          ylim = (105_000,135_000),
                                          grid = True,
                                          legend = False,
                                          figsize = (7,9),
                                          title = ('Зависимость цены за кв.м от этажа квартиры'))
ax.set_xlabel('Этаж')
ax.set_ylabel('Цена за кв.м, рубли');

# %% [markdown]
# ##### Вывод

# %% [markdown]
# - Показатели сходны с общими по датафрейму.
# - Цена за кв.м. в центре ниже у квартир, расположенных на первом этаже. Самая высокая цена у квартир расположенными между первым и посленим этажами.

# %% [markdown]
# #### Зависимость цены за кв.м от площади квартиры

# %%
ax = df_center.pivot_table(index ='total_area_grouped',
                        values = 'sq_m_price',
                        aggfunc = 'mean').plot(kind = 'bar',
                                               grid = True,
                                               ylim = (100_000,170_000),
                                               legend = False,
                                               figsize = (10,7),
                                               title = ('Зависимость цены за кв.м. от площади квартиры'))
ax.set_xlabel('Площадь квартиры в кв.м, до')
ax.set_ylabel('Цена за кв.м, рубли');

# %% [markdown]
# ##### Вывод

# %% [markdown]
# > Есть некоторые небольшие отличия от общей картины, если говорить о зависимости цены за кв.м. от площади квартиры в центре Питера.
# - Самая высокая цена за квадратный метр на квартиры **до 20 и 30 кв.м.**
# - Цена за кв.м. у квартир площадью **от 50 до 80 кв.м.** выше,чем у квартир **до 40 кв.м.**. Скорее всего это стандартные размеры квартир отреставрированного жилого фонда старой застройки с высокими потолками.
# - Квартиры **от 20 до 80 кв.м.** стоят дороже квартир **от 100 до 125 кв.м.** *в пересчете на квадратный метр*, так как, опять же, пользуются крайне высоким спросом у молодежи и небольших семей без детей или с одним ребенок.
# - В сегментах квартир общей площадью от **100 кв.м. до 150 кв.м.** наблюдется существенный рост стоимости кв.м., как и в общем по всему набору данных. Такой рост стоимости обусловен "премиум-сегментом" таких квартир, чаще всего они имеют дополнительные бонусы, которые не отражены в данном датафрейме, такие как охраняемые парковки, дополнительные удобства на территории, клубные дома это или нет и прочее.
# - В сегменте квартир **выше 150 кв.м.** опять видно падение относительной стоимости в пересчете на квадратный метр, так как эти квартиры того же сегмента, что и прошлый и подчиняются ровно той же зависимости, что и обычные одно- и двухкомнатные квартиры.

# %% [markdown]
# #### Зависимость цены за кв.м от числа комнат

# %%
ax = df_center.pivot_table(index = 'rooms',
                        values = 'sq_m_price',
                        aggfunc = 'median').plot(kind = 'bar',
                                               grid = True,
                                               ylim = (90_000,145_000),
                                               figsize = (10,7),
                                               legend = False,
                                               title = ('Зависимость цены за кв.м. количества комнат в Санкт-Петербурге'))
ax.set_xlabel('Комнат')
ax.set_ylabel('Цена за кв.м, рубли');

# %% [markdown]
# > Зависимость идентична зависимости по всему датафрейму.

# %% [markdown]
# ##### Вывод

# %% [markdown]
# Так же как и в общем, зависимость схожа с общими данными по всем населенным пунктам. Вывод идентичен выводу в п. 4.6.1

# %% [markdown]
# #### Зависимость стоимости от даты размещения

# %% [markdown]
# ##### От года размещения

# %%
ax = df_center.pivot_table(index = 'year',
                   values = 'sq_m_price',
                   aggfunc = 'median').plot(kind='line',
                                            ylim = (100_000,160_000),
                                            grid = True,
                                            legend = False,
                                            figsize = (7,9),
                                            title = ('Зависимость цены за кв.м. в зависимости от года публикации'))
ax.set_xlabel('Год')
ax.set_ylabel('Цена за кв.м.');

# %% [markdown]
# > Цена за квадратный метр начала резко снижаться вплоть до 2016 года, в котором достигла минимумма.
# Жилье покупается и продается, но львиная доля приобретенных квартир снова выставляется на продажу с целью инвестирования в другую жилплощадь.Процессы замедлились из-за сокращения заработной платы в среднем на 7-9,5%, скачков валют, неподъемных сумм по обеспечению кредитов. Результат: заморозка строек, банкротство девелоперских компаний (по некоторым данным, их более 2,5 тысяч, в 5 раз больше прошлогодних показателей)
#
# [подтверждение](https://mirndv.ru/blog/ceny-na-novostrojki-v-blizhajshie-gody/)

# %% [markdown]
# ##### От месяца размещения

# %%
df_center['month'].value_counts()
# Out:
# февраль     21
# сентябрь    19
# июль        19
# июнь        17
# ноябрь      16
# март        14
# декабрь     13
# апрель      13
# май         11
# август      10
# октябрь      9
# январь       8
# Name: month, dtype: int64

# %%
ax = df_center.pivot_table(index = 'month1',
                   values = 'sq_m_price').plot(kind='bar',
                                               ylim = (90_000,160_000),
                                               grid = True,
                                               figsize = (7,9),
                                               legend = None,
                                               title = ('Зависимость цены продажи от месяца'))
ax.set_xlabel('Месяц')
ax.set_ylabel('Цена за кв.м.');

# %% [markdown]
# >  Самые низкие цены за кв.м. в объявлениях, размещенных в декабре и июле. Понижение цены в декабре можно объяснить новогодним ажиотажем на рынке недвижимости, связанным с общим понижением цены у застройщиков в виду новогодних скидок у крупных застройщиков, которые оказывают демпинговое влиние на рынок в целом,в том числе и частный сектор,понижая цену на кв.м. для всего рынка недвижимости. Пониженная цена в июле связана с продолжением дачного сезона и сезона отпусков,а так же  и пониженным спросом на жилье, из-за чего снижается покупательная способность и цены закономерно становятся ниже. Относительно низкие цены на недвижимость наблюдаются так же в июне,что связано с сезоном отпусков.
# В сентрябре начинается резкое повышение цен на кв.м. Это связано с тем, что спрос на рынок недвижимости растет, все возвращаются из отпусков и повышается интерес к рынку недвижимости - увеличивается спрос, и как следствие, растут цены на недвижимость. То же самое и с маем,все пытаются решить жилищный вопрос до наступления сезлна отпусков.

# %% [markdown]
# ##### От дня размещения

# %%
ax = df_center.pivot_table(index = 'week_day1',
                        values = 'sq_m_price',
                        aggfunc = 'median').plot(kind='bar',
                                                 ylim = (90_000,130_000),
                                                 grid = True,
                                                 figsize = (7,10),
                                                 legend = None,
                                                 title = ('Зависимость цены продажи от дня'))
ax.set_xlabel('День недели')
ax.set_ylabel('Цена за кв.м.');

# %% [markdown]
# > Самая высокая цена у объявлений, размещенных в понедельник и вторник,самая низкая - в воскресенье. Первый факт можно объяснить тем, что биржа обновляет курс валют в понедельник, так как в выходные биржа не работает. Опять же,многих не бывает на выходных в городе и они не готовы заниматься продажей жилья. Многие так же берут отпуск,начиная с понедельника,чтобы не сокращать себе отпуск за счет выходных. И начинают заниматься продажей квартиры именно  с понедельника. С другой стороны такую низкую цену в воскресенье можно объяснить тем, что люди, продающие недвижимость, могут рассчитывать продать ее быстрее, снижая цену, что сказывается на распределении.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Итак,
# > общие зависимости сходны с зависимостями параметров квартир в центре Санкт-Петербурга.
#
# В общем, мы выяснили:
# - В центре Питера квартиры бОльшей квадратуры и чаще встречаются квартиры с более высокими потолками от 3 до 3.8 м;
# - Относительная цена за квадратный метр выше у квартир с меньшим количеством комнат и меньшей общей площадью;
# - Квартиры, расположенные на этажах между первым и последним статистически стоят дороже;
# - Чем ближе к центру Санкт-Петербурга, тем выше стоимость кв.м., область центра города - примерно 3 километра  в диаметре;
# - Большая часть квартир в центре Питера имеет высоту потолков от 2.5 до 3 метров, более высокие встречаются реже и чаще в Питере,нежели в отдалении от центра.
# - Квадратура квартир в центре Санкт-Петербурга относительно комнат больше, чем у аналогов на расстоянии от центра;
# - День недели слабо влияет на цену недвижимости, но лучше покупать недвижимость до или после сезона отпусков и дачного сезона;
# - Касаемо года, цена на недвижимость и цена на кв.м. во всех секторах планомерно растёт;
# - Большая часть объявлений приходится на центр Питера и его ближайшие окрестности, но встречаются и большие скопления в отдалении - это новые жилые массивы с большим количеством квартир, которые строятся дальше из-за более дешевой цены на землю;
# - В центре Питера гораздо меньше квартир-студий,чем в более отдаленных районах;
# - Квартиры в центре стоят, очевидно, дороже аналогов на отдалении от центра;
# - Если объявление выставлено больше 260 дней назад, требуется снизить цену или улучшить условия.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Вывод хороший. В идеале стоит добавить медианы основных характеристик квартир для центра (после корректировок) и для всей выборки, чтобы заказчику было понятно не только то, что квартиры в центре больше и дороже, но и насколько они больше и насколько дороже.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# После выводов добавил сводные таблицы по трем выборкам:
# 1) Oбщая;
#
# 2) Санкт-Петербург;
#
# 3) Центр Санкт-Петербурга;</div>

# %% [markdown]
# ## Сводная таблица по характеристикам

# %% [markdown]
# ### Вся выборка

# %%
df_new.pivot_table(index = 'total_area_grouped',
                      values=['sq_m_price','total_area', 'rooms','ceiling_height', 'live_s/all_s','kitchen_s/all_s'],
                      aggfunc = 'median').style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
#     #T_73e3913a_8271_11ec_8f30_02420a3944barow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73e3913a_8271_11ec_8f30_02420a3944barow0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73e3913a_8271_11ec_8f30_02420a3944barow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73e3913a_8271_11ec_8f30_02420a3944barow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73e3913a_8271_11ec_8f30_02420a3944barow0_col4 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_73e3913a_8271_11ec_8f30_02420a3944barow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73e3913a_8271_11ec_8f30_02420a3944barow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# ### Выборка по  Санкт-Петербургу

# %%
df_spb.pivot_table(index = 'total_area_grouped',
                      values=['sq_m_price','total_area', 'rooms','ceiling_height', 'live_s/all_s','kitchen_s/all_s'],
                      aggfunc = 'median').style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
#     #T_73ecde20_8271_11ec_8f30_02420a3944barow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73ecde20_8271_11ec_8f30_02420a3944barow0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73ecde20_8271_11ec_8f30_02420a3944barow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73ecde20_8271_11ec_8f30_02420a3944barow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73ecde20_8271_11ec_8f30_02420a3944barow0_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73ecde20_8271_11ec_8f30_02420a3944barow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73ecde20_8271_11ec_8f30_02420a3944barow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# ### Выборка по центру Санкт - Петербурга

# %%
df_center.pivot_table(index = 'total_area_grouped',
                      values=['sq_m_price','total_area', 'rooms','ceiling_height', 'live_s/all_s','kitchen_s/all_s'],
                      aggfunc = 'median').style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
#     #T_73f79b1c_8271_11ec_8f30_02420a3944barow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f79b1c_8271_11ec_8f30_02420a3944barow0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73f79b1c_8271_11ec_8f30_02420a3944barow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f79b1c_8271_11ec_8f30_02420a3944barow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f79b1c_8271_11ec_8f30_02420a3944barow0_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73f79b1c_8271_11ec_8f30_02420a3944barow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f79b1c_8271_11ec_8f30_02420a3944barow1_col0 {
#             background-color:  #e7745b;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Отлично :) Можно еще тезисами перечислить :) </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
